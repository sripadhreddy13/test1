# %% [markdown]
# <a href="https://colab.research.google.com/github/sripadhreddy13/test1/blob/main/lab_actv_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: import a file from google drive

from google.colab import drive
drive.mount('/content/drive')
#The path may need to be adjusted depending on where your file is located in Drive
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/D.O LAB/question_1.xlsx') #Replace your_file.csv with the actual file name
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-cdc9d3ca5809> in <cell line: 0>()
#       5 #The path may need to be adjusted depending on where your file is located in Drive
#       6 import pandas as pd
# ----> 7 df = pd.read_csv('/content/drive/MyDrive/D.O LAB/question_1.xlsx') #Replace your_file.csv with the actual file name
#       8 print(df.head())
#
# ...

# %%
import pandas as pd

# Try reading the file using 'latin-1' encoding
df = pd.read_csv('/content/drive/MyDrive/D.O LAB/question_1.xlsx', encoding='latin-1')
# If 'latin-1' doesn't work, try other encodings like 'cp1252', 'iso-8859-1', etc.

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-d7dfccb174e4> in <cell line: 0>()
#       2
#       3 # Try reading the file using 'latin-1' encoding
# ----> 4 df = pd.read_csv('/content/drive/MyDrive/D.O LAB/question_1.xlsx', encoding='latin-1')
#       5 # If 'latin-1' doesn't work, try other encodings like 'cp1252', 'iso-8859-1', etc.
#       6
#
# ...

# %%
import pandas as pd

# Try reading the file using 'latin-1' encoding and specifying the delimiter
# If you know the delimiter, replace '\t' with the actual delimiter
# like ',' for comma, ';' for semicolon, etc.
try:
    df = pd.read_csv('/content/drive/MyDrive/D.O LAB/question_1.xlsx', encoding='latin-1', delimiter=',')
    print(df.head())
except pd.errors.ParserError as e:
    print(f"Error reading file: {e}")
    # If error persists, open the file in a text editor and examine line 5 to
    # identify the cause of the extra field. You might need to handle it manually
    # before reading the file into pandas.
    # You can also try skipping the problematic row with skiprows=[4]
    # (skips the 5th row which is index 4)
    # df = pd.read_csv('/content/drive/MyDrive/D.O LAB/question_1.xlsx', encoding='latin-1', delimiter=',', skiprows=[4])
    # print(df.head())
# Out:
# Error reading file: Error tokenizing data. C error: Expected 3 fields in line 5, saw 4

# %%
file_path = '/content/drive/MyDrive/D.O LAB/question_1.xlsx'
df = pd.read_csv(file_path, encoding='latin-1', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-773f3bb207f0> in <cell line: 0>()
#       1 file_path = '/content/drive/MyDrive/D.O LAB/question_1.xlsx'
# ----> 2 df = pd.read_csv(file_path, encoding='latin-1', delimiter=',')
#
# ...

# %%
# !pip install openpyxl
import pandas as pd

file_path = '/content/drive/MyDrive/D.O LAB/question_1.xlsx'

# Use read_excel instead of read_csv for Excel files
df = pd.read_excel(file_path)

# If you still face issues, you might need to handle specific errors.
# Try to inspect line 5 in your Excel file to understand the issue
# and then consider these options:

# 1. If the issue is an extra delimiter on line 5, you could try to read the file as text,
#    clean the problematic line, and then read it into pandas.
# 2. If the issue is extra data, you could use the 'usecols' parameter in read_excel
#    to specify the columns you want to read.
# 3. If the issue is complex, you could use a library like 'xlrd' for more control
#    over reading Excel files.

# %%
df.describe()
# Out:
#        math score  reading score  writing score        Total          Max  \
# count  1000.00000    1000.000000    1000.000000  1000.000000  1000.000000
# mean     66.08900      69.169000      68.054000   203.312000    72.396000
# std      15.16308      14.600192      15.195657    42.771978    14.240083
# min       0.00000      17.000000      10.000000    27.000000    17.000000
# 25%      57.00000      59.000000      57.750000   175.000000    62.000000
# 50%      66.00000      70.000000      69.000000   205.000000    73.000000
# 75%      77.00000      79.000000      79.000000   233.000000    82.000000
# max     100.00000     100.000000     100.000000   300.000000   100.000000
#
#                Min          Avg
# count  1000.000000  1000.000000
# mean     62.607000    67.770667
# std      14.676374    14.257326
# min       0.000000     9.000000
# 25%      53.000000    58.333333
# 50%      63.000000    68.333333
# 75%      73.000000    77.666667
# max     100.000000   100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   Total                        1000 non-null   int64
#  9   Max                          1000 non-null   int64
#  10  Min                          1000 non-null   int64
#  11  Avg                          1000 non-null   float64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 93.9+ KB

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  Total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#    Max  Min        Avg
# 0   74   72  72.666667
# 1   90   69  82.333333
# 2   95   90  92.666667
# ...

# %%
df['Total'] = df[['math score', 'reading score', 'writing score']].sum(axis=1)
df['Max'] = df[['math score', 'reading score', 'writing score']].max(axis=1)
df['Min'] = df[['math score', 'reading score', 'writing score']].min(axis=1)
df['Avg'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  Total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#    Max  Min        Avg
# 0   74   72  72.666667
# 1   90   69  82.333333
# 2   95   90  92.666667
# ...

# %%
import matplotlib.pyplot as plt
df['Max'].plot(kind='hist', bins=10, color='cyan', edgecolor='black', title='histogram of max')
plt.xlabel('')
plt.ylabel('Frequency')
plt.show()
